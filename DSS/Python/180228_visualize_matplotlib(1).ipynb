# %% [markdown]
# ## visualize
#
# 1. matplotlib
# 1. seaborn
# 1. pandas

# %% [markdown]
# ### 1. matplotlib

# %%
# %matplotlib inline

# %%
# %config InlineBackend.figure_formats = {'png', 'retina'}

# %%
plt.plot([1, 3, 7, 10]) #basic
plt.show()

# %%
plt.plot([1, 3, 7, 10],
         c='r', # color 
         lw=4, #  linewitdth
         ls='--', # linestyle
         marker='h', # marker type
         ms='15', # marker size
         mfc='w', # marker face color
         mew='3', # marker edge width
         mec = 'k') # marker edge color
plt.show()

# %%
plt.plot([1, 3, 7, 10], '--sr') # 간략하게 color, linestyle, markerstyle 순서상관x
plt.show()

# %% [markdown]
# ### color
# (b)lue, (g)reen, (r)ed, (c)yan, (m)agenta, (y)ellow, (w)hite, blac(k)

# %% [markdown]
# ### marker
# (.) point, (,) pixel, (o) circle
#
# (v) triangle_down, (^) triangle_up, (<), (>)
#
# (1) tri_down, (2) tri_up, (3), (4)
#
# (s)quare, (p)entagon, (*) star, (h)exagon, (H)exagon
#
# +, x, (D)iamond, (d)iamond

# %% [markdown]
# ### line
#
# (-), (--), (-.), (:)

# %% [markdown]
# ### xlim, ylim -> 범위 지정

# %%
plt.plot([1, 3, 7, 10])
plt.xlim(-10, 10)
plt.ylim(-5, 15)
plt.show()

# %% [markdown]
# ### tick 설정

# %%
plt.plot([1, 3, 7, 10])
plt.xticks(range(5))
plt.yticks(range(13))
plt.show()

# %%
plt.plot([1, 3, 7, 10])
plt.xticks(range(5), [0, 'latax:$\sigma^2$', 'string', 'ok']) # xtick 수동 설정
plt.yticks(range(13))
plt.grid(False) # 그리드 제거
plt.show()

# %% [markdown]
# ### multiline

# %%
t = np.arange(0., 5., 0.2)

# 라인마다 스타일, xtick 설정 해줘야 함
plt.plot(t, t, 'r--', 
          t, 0.5 * t**2, 'bs:', 
          t, 0.2 * t**3, 'g^-')

#plt.plot(xticks, data1, 'ro-', / xticks, data2, 'gs:', / xticks, data3, 'b*--')

plt.show()

# %%
plt.plot([1, 2, 3, 4], 's:r', label='data1')
#plt.hold(True) 1.5 버전에서는 홀드 명령이 필요했다.
plt.plot([2, 3, 2, 3], '-b^', label='data2')
#plt.hold(False) : 2.0부터는 자동 적용

plt.legend(loc=0) # 범례 추가 
plt.show()

# %% [markdown]
# ### label, title 추가

# %%
plt.plot(np.random.randint(5, size=5))
plt.xlabel("xtick")
plt.ylabel("ytick")
plt.title("title")
plt.show()

# %% [markdown]
# ### figure, subplot

# %%
f1 = plt.figure(figsize=(15,5), # 그래프 크기 조절
                    facecolor='g', 
                    linewidth=10, # linewidth default 때는 색 바꿔도 안보임...
                    edgecolor='b',
                    ) 

plt.subplot(2,1,1) # 2 * 1 에서 1 번 위치 
plt.plot(np.random.randint(5, size=5), '-r')

plt.subplot(2,1,2)
plt.plot(np.random.randint(5, size=5))

plt.tight_layout() # 플롯간 간격 자동 맞춤
plt.show()

# %%
fig, axes = plt.subplots(2, 2)

axes[0, 0].plot(np.random.rand(5))
axes[0, 0].set_title("axes 1")
axes[0, 0].set_xlabel("xlabel 1")
axes[0, 0].set_ylabel("ylabel 1")

axes[0, 1].plot(np.random.rand(5))
axes[0, 1].set_title("axes 2")
axes[1, 0].plot(np.random.rand(5))
axes[1, 0].set_title("axes 3")
axes[1, 1].plot(np.random.rand(5))
axes[1, 1].set_title("axes 4")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### semilog
# 부분 확대 가능

# %%
plt.subplots_adjust(hspace=0.4)
t = np.arange(0.01, 20.0, 0.01)

# log y axis
plt.subplot(221)
plt.semilogy(t, np.exp(-t/5.0))
plt.title('semilogy')
plt.grid(True)

# log x axis
plt.subplot(222)
plt.semilogx(t, np.sin(2*np.pi*t))
plt.title('semilogx')
plt.grid(True)

# log x and y axis
plt.subplot(223)
plt.loglog(t, 20*np.exp(-t/10.0), basex=2)
plt.grid(True)
plt.title('loglog base 2 on x')

# with errorbars: clip non-positive values
ax = plt.subplot(224)
ax.set_xscale("log", nonposx='clip')
ax.set_yscale("log", nonposy='clip')

x = 10.0**np.linspace(0.0, 2.0, 20)
y = x**2.0
plt.errorbar(x, y, xerr=0.1*x, yerr=5.0 + 0.75*y)
ax.set_ylim(ymin=0.1)
ax.set_title('Errorbars go negative')


plt.show()
